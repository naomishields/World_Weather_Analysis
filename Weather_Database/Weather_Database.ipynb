# %%
#Import dependencies
import pandas as pd
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 768

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | westport
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | narsaq
# Processing Record 7 of Set 1 | shimoda
# Processing Record 8 of Set 1 | saint-joseph
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | barrow
# Processing Record 12 of Set 1 | polunochnoye
# Processing Record 13 of Set 1 | ilhabela
# Processing Record 14 of Set 1 | jos
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | bela vista
# Processing Record 17 of Set 1 | kelme
# Processing Record 18 of Set 1 | vardo
# Processing Record 19 of Set 1 | huilong
# Processing Record 20 of Set 1 | clyde river
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | bethel
# Processing Record 23 of Set 1 | kasempa
# Processing Record 24 of Set 1 | bathsheba
# Processing Record 25 of Set 1 | kapaa
# Processing Record 26 of Set 1 | arraial do cabo
# Processing Record 27 of Set 1 | lorengau
# Processing Record 28 of Set 1 | carnarvon
# Processing Record 29 of Set 1 | port lincoln
# Processing Record 30 of Set 1 | belyy yar
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | namibe
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | marsa matruh
# Processing Record 35 of Set 1 | louis trichardt
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | charters towers
# Processing Record 38 of Set 1 | la ronge
# Processing Record 39 of Set 1 | kruisfontein
# Processing Record 40 of Set 1 | vao
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | kuala kedah
# Processing Record 43 of Set 1 | iralaya
# Processing Record 44 of Set 1 | sabang
# Processing Record 45 of Set 1 | richards bay
# Processing Record 46 of Set 1 | ak-dovurak
# Processing Record 47 of Set 1 | georgetown
# Processing Record 48 of Set 1 | hambantota
# Processing Record 49 of Set 1 | port hawkesbury
# Processing Record 50 of Set 1 | nakhon si thammarat
# Processing Record 1 of Set 2 | huarmey
# Processing Record 2 of Set 2 | ayagoz
# Processing Record 3 of Set 2 | sfantu gheorghe
# Processing Record 4 of Set 2 | ndioum
# Processing Record 5 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 2 | naze
# Processing Record 7 of Set 2 | shiyan
# Processing Record 8 of Set 2 | aasiaat
# Processing Record 9 of Set 2 | paamiut
# Processing Record 10 of Set 2 | mataura
# Processing Record 11 of Set 2 | chokurdakh
# Processing Record 12 of Set 2 | kodiak
# Processing Record 13 of Set 2 | vostok
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | puerto ayora
# Processing Record 16 of Set 2 | abalak
# Processing Record 17 of Set 2 | port alfred
# Processing Record 18 of Set 2 | maniitsoq
# Processing Record 19 of Set 2 | kristiansund
# Processing Record 20 of Set 2 | hermanus
# Processing Record 21 of Set 2 | iqaluit
# Processing Record 22 of Set 2 | torbay
# Processing Record 23 of Set 2 | east london
# Processing Record 24 of Set 2 | hilo
# Processing Record 25 of Set 2 | lagoa
# Processing Record 26 of Set 2 | beatrice
# Processing Record 27 of Set 2 | hualmay
# Processing Record 28 of Set 2 | new norfolk
# Processing Record 29 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 2 | whithorn
# Processing Record 31 of Set 2 | sambava
# Processing Record 32 of Set 2 | ahipara
# Processing Record 33 of Set 2 | ribeira grande
# Processing Record 34 of Set 2 | manadhoo
# Processing Record 35 of Set 2 | xuddur
# Processing Record 36 of Set 2 | albany
# Processing Record 37 of Set 2 | lebu
# Processing Record 38 of Set 2 | muros
# Processing Record 39 of Set 2 | zalesovo
# Processing Record 40 of Set 2 | alyangula
# Processing Record 41 of Set 2 | saint-philippe
# Processing Record 42 of Set 2 | khawhai
# Processing Record 43 of Set 2 | paita
# Processing Record 44 of Set 2 | anadyr
# Processing Record 45 of Set 2 | banda aceh
# Processing Record 46 of Set 2 | mahebourg
# Processing Record 47 of Set 2 | palmer
# Processing Record 48 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 2 | the valley
# Processing Record 50 of Set 2 | mutsamudu
# City not found. Skipping...
# Processing Record 1 of Set 3 | kloulklubed
# Processing Record 2 of Set 3 | tautira
# Processing Record 3 of Set 3 | labuhan
# Processing Record 4 of Set 3 | huanren
# Processing Record 5 of Set 3 | mount isa
# Processing Record 6 of Set 3 | alofi
# Processing Record 7 of Set 3 | norman wells
# Processing Record 8 of Set 3 | gambissara
# Processing Record 9 of Set 3 | vagur
# Processing Record 10 of Set 3 | fortuna
# Processing Record 11 of Set 3 | vila velha
# Processing Record 12 of Set 3 | kidal
# Processing Record 13 of Set 3 | birjand
# Processing Record 14 of Set 3 | codrington
# Processing Record 15 of Set 3 | palauig
# Processing Record 16 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 3 | gangotri
# City not found. Skipping...
# Processing Record 18 of Set 3 | el paso
# Processing Record 19 of Set 3 | puerto cabezas
# Processing Record 20 of Set 3 | asau
# Processing Record 21 of Set 3 | punta arenas
# Processing Record 22 of Set 3 | mattru
# Processing Record 23 of Set 3 | plettenberg bay
# Processing Record 24 of Set 3 | kahului
# Processing Record 25 of Set 3 | faanui
# Processing Record 26 of Set 3 | tasiilaq
# Processing Record 27 of Set 3 | jamestown
# Processing Record 28 of Set 3 | ksenyevka
# City not found. Skipping...
# Processing Record 29 of Set 3 | petropavlovka
# Processing Record 30 of Set 3 | alta floresta
# Processing Record 31 of Set 3 | kaitangata
# Processing Record 32 of Set 3 | aklavik
# Processing Record 33 of Set 3 | storforshei
# Processing Record 34 of Set 3 | chalon-sur-saone
# Processing Record 35 of Set 3 | emba
# Processing Record 36 of Set 3 | port antonio
# Processing Record 37 of Set 3 | daru
# Processing Record 38 of Set 3 | nanzhang
# Processing Record 39 of Set 3 | horsham
# Processing Record 40 of Set 3 | cherskiy
# Processing Record 41 of Set 3 | mar del plata
# Processing Record 42 of Set 3 | isangel
# Processing Record 43 of Set 3 | micheweni
# Processing Record 44 of Set 3 | serrana
# Processing Record 45 of Set 3 | lodwar
# Processing Record 46 of Set 3 | bengkulu
# Processing Record 47 of Set 3 | christchurch
# Processing Record 48 of Set 3 | katsuura
# Processing Record 49 of Set 3 | tamandare
# Processing Record 50 of Set 3 | sao miguel do araguaia
# Processing Record 1 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 2 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 3 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 4 | turukhansk
# Processing Record 5 of Set 4 | pochutla
# Processing Record 6 of Set 4 | saldanha
# Processing Record 7 of Set 4 | khatanga
# Processing Record 8 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 4 | barguzin
# Processing Record 10 of Set 4 | stephenville crossing
# Processing Record 11 of Set 4 | kavieng
# Processing Record 12 of Set 4 | longyearbyen
# Processing Record 13 of Set 4 | san julian
# Processing Record 14 of Set 4 | zapolyarnyy
# Processing Record 15 of Set 4 | upernavik
# Processing Record 16 of Set 4 | yellowknife
# Processing Record 17 of Set 4 | saint anthony
# Processing Record 18 of Set 4 | sao felix do xingu
# Processing Record 19 of Set 4 | mount gambier
# Processing Record 20 of Set 4 | hukuntsi
# Processing Record 21 of Set 4 | ponta do sol
# Processing Record 22 of Set 4 | bilibino
# Processing Record 23 of Set 4 | kushiro
# Processing Record 24 of Set 4 | uberaba
# Processing Record 25 of Set 4 | beringovskiy
# Processing Record 26 of Set 4 | airai
# Processing Record 27 of Set 4 | hay river
# Processing Record 28 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 4 | severo-kurilsk
# Processing Record 30 of Set 4 | gien
# Processing Record 31 of Set 4 | gushikawa
# Processing Record 32 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 4 | waddan
# Processing Record 34 of Set 4 | meulaboh
# Processing Record 35 of Set 4 | dikson
# Processing Record 36 of Set 4 | nome
# Processing Record 37 of Set 4 | qianguo
# Processing Record 38 of Set 4 | warri
# Processing Record 39 of Set 4 | bredasdorp
# Processing Record 40 of Set 4 | innisfail
# Processing Record 41 of Set 4 | tuktoyaktuk
# Processing Record 42 of Set 4 | cabadiangan
# Processing Record 43 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 44 of Set 4 | campo verde
# Processing Record 45 of Set 4 | esperance
# Processing Record 46 of Set 4 | sokoto
# Processing Record 47 of Set 4 | tunduru
# City not found. Skipping...
# Processing Record 48 of Set 4 | mogadishu
# Processing Record 49 of Set 4 | strezhevoy
# Processing Record 50 of Set 4 | saint-augustin
# Processing Record 1 of Set 5 | bodmin
# Processing Record 2 of Set 5 | caravelas
# Processing Record 3 of Set 5 | stratford
# Processing Record 4 of Set 5 | kimbe
# Processing Record 5 of Set 5 | nikolskoye
# Processing Record 6 of Set 5 | souillac
# Processing Record 7 of Set 5 | aswan
# Processing Record 8 of Set 5 | pevek
# Processing Record 9 of Set 5 | prado
# Processing Record 10 of Set 5 | dwarka
# Processing Record 11 of Set 5 | along
# Processing Record 12 of Set 5 | geraldton
# Processing Record 13 of Set 5 | havoysund
# Processing Record 14 of Set 5 | sobolevo
# Processing Record 15 of Set 5 | san
# Processing Record 16 of Set 5 | goundam
# Processing Record 17 of Set 5 | thompson
# Processing Record 18 of Set 5 | itanhaem
# Processing Record 19 of Set 5 | leningradskiy
# Processing Record 20 of Set 5 | vila franca do campo
# Processing Record 21 of Set 5 | manokwari
# Processing Record 22 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 23 of Set 5 | el wasta
# City not found. Skipping...
# Processing Record 24 of Set 5 | shiraz
# Processing Record 25 of Set 5 | tuatapere
# Processing Record 26 of Set 5 | melbourne
# Processing Record 27 of Set 5 | pertuis
# Processing Record 28 of Set 5 | hasaki
# Processing Record 29 of Set 5 | nuuk
# Processing Record 30 of Set 5 | itarema
# Processing Record 31 of Set 5 | stornoway
# Processing Record 32 of Set 5 | burica
# City not found. Skipping...
# Processing Record 33 of Set 5 | port hardy
# Processing Record 34 of Set 5 | bousso
# Processing Record 35 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 36 of Set 5 | bichena
# Processing Record 37 of Set 5 | balingasay
# Processing Record 38 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 5 | qaanaaq
# Processing Record 41 of Set 5 | cabo san lucas
# Processing Record 42 of Set 5 | hithadhoo
# Processing Record 43 of Set 5 | sovetskiy
# Processing Record 44 of Set 5 | gamba
# Processing Record 45 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 5 | chiapa
# Processing Record 49 of Set 5 | montrose
# Processing Record 50 of Set 5 | urucara
# Processing Record 1 of Set 6 | whitehorse
# Processing Record 2 of Set 6 | srednekolymsk
# Processing Record 3 of Set 6 | sao gabriel da cachoeira
# Processing Record 4 of Set 6 | chuy
# Processing Record 5 of Set 6 | middelburg
# Processing Record 6 of Set 6 | araouane
# Processing Record 7 of Set 6 | comodoro rivadavia
# Processing Record 8 of Set 6 | kamaishi
# Processing Record 9 of Set 6 | smithers
# Processing Record 10 of Set 6 | qeshm
# Processing Record 11 of Set 6 | tessalit
# Processing Record 12 of Set 6 | cam ranh
# Processing Record 13 of Set 6 | burnie
# Processing Record 14 of Set 6 | kyabe
# Processing Record 15 of Set 6 | bakaly
# Processing Record 16 of Set 6 | roseburg
# Processing Record 17 of Set 6 | bozoum
# Processing Record 18 of Set 6 | balkanabat
# Processing Record 19 of Set 6 | turkistan
# Processing Record 20 of Set 6 | adrar
# Processing Record 21 of Set 6 | matara
# Processing Record 22 of Set 6 | tiksi
# Processing Record 23 of Set 6 | guanambi
# Processing Record 24 of Set 6 | kiama
# Processing Record 25 of Set 6 | zhigansk
# Processing Record 26 of Set 6 | pedernales
# Processing Record 27 of Set 6 | prainha
# Processing Record 28 of Set 6 | mantua
# Processing Record 29 of Set 6 | dakoro
# Processing Record 30 of Set 6 | luderitz
# Processing Record 31 of Set 6 | rocha
# Processing Record 32 of Set 6 | kikwit
# Processing Record 33 of Set 6 | namatanai
# Processing Record 34 of Set 6 | saint-agapit
# Processing Record 35 of Set 6 | linares
# Processing Record 36 of Set 6 | dagana
# Processing Record 37 of Set 6 | chaozhou
# Processing Record 38 of Set 6 | manono
# Processing Record 39 of Set 6 | matamoros
# Processing Record 40 of Set 6 | north bend
# Processing Record 41 of Set 6 | flinders
# Processing Record 42 of Set 6 | barcelona
# Processing Record 43 of Set 6 | mahibadhoo
# Processing Record 44 of Set 6 | san patricio
# Processing Record 45 of Set 6 | inyonga
# Processing Record 46 of Set 6 | yulara
# Processing Record 47 of Set 6 | sitka
# Processing Record 48 of Set 6 | vestmannaeyjar
# Processing Record 49 of Set 6 | northam
# Processing Record 50 of Set 6 | barinitas
# Processing Record 1 of Set 7 | vasylivka
# Processing Record 2 of Set 7 | tateyama
# Processing Record 3 of Set 7 | ilulissat
# Processing Record 4 of Set 7 | san ramon
# Processing Record 5 of Set 7 | biloela
# Processing Record 6 of Set 7 | bairnsdale
# Processing Record 7 of Set 7 | penugonda
# Processing Record 8 of Set 7 | chapais
# Processing Record 9 of Set 7 | nemuro
# Processing Record 10 of Set 7 | rio gallegos
# Processing Record 11 of Set 7 | tucupita
# Processing Record 12 of Set 7 | trairi
# Processing Record 13 of Set 7 | saint-francois
# Processing Record 14 of Set 7 | kysyl-syr
# Processing Record 15 of Set 7 | sao joao da barra
# Processing Record 16 of Set 7 | mahajanga
# Processing Record 17 of Set 7 | tungkang
# City not found. Skipping...
# Processing Record 18 of Set 7 | matane
# Processing Record 19 of Set 7 | kolyshley
# Processing Record 20 of Set 7 | victoria
# Processing Record 21 of Set 7 | kolokani
# Processing Record 22 of Set 7 | lavrentiya
# Processing Record 23 of Set 7 | san rafael
# Processing Record 24 of Set 7 | port blair
# Processing Record 25 of Set 7 | buala
# Processing Record 26 of Set 7 | bandarbeyla
# Processing Record 27 of Set 7 | kjollefjord
# Processing Record 28 of Set 7 | wang saphung
# Processing Record 29 of Set 7 | yalova
# Processing Record 30 of Set 7 | arkhara
# Processing Record 31 of Set 7 | balaka
# Processing Record 32 of Set 7 | solnechnyy
# Processing Record 33 of Set 7 | goundi
# Processing Record 34 of Set 7 | linqu
# Processing Record 35 of Set 7 | uturoa
# Processing Record 36 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 7 | lakes entrance
# Processing Record 38 of Set 7 | macusani
# Processing Record 39 of Set 7 | nara
# Processing Record 40 of Set 7 | dudinka
# Processing Record 41 of Set 7 | hadgaon
# Processing Record 42 of Set 7 | shakawe
# Processing Record 43 of Set 7 | cockburn town
# Processing Record 44 of Set 7 | sola
# Processing Record 45 of Set 7 | touros
# Processing Record 46 of Set 7 | moose factory
# Processing Record 47 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 48 of Set 7 | megion
# Processing Record 49 of Set 7 | alice town
# Processing Record 50 of Set 7 | aras
# Processing Record 1 of Set 8 | zaraza
# Processing Record 2 of Set 8 | tuy hoa
# Processing Record 3 of Set 8 | moerai
# Processing Record 4 of Set 8 | olafsvik
# Processing Record 5 of Set 8 | siniscola
# Processing Record 6 of Set 8 | nakapiripirit
# Processing Record 7 of Set 8 | husavik
# Processing Record 8 of Set 8 | orange
# Processing Record 9 of Set 8 | bambous virieux
# Processing Record 10 of Set 8 | acarau
# Processing Record 11 of Set 8 | sao filipe
# Processing Record 12 of Set 8 | timizart
# Processing Record 13 of Set 8 | palana
# Processing Record 14 of Set 8 | walvis bay
# Processing Record 15 of Set 8 | nizhniy tsasuchey
# Processing Record 16 of Set 8 | lar gerd
# City not found. Skipping...
# Processing Record 17 of Set 8 | sokoni
# Processing Record 18 of Set 8 | xinxiang
# Processing Record 19 of Set 8 | faya
# Processing Record 20 of Set 8 | talara
# Processing Record 21 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 22 of Set 8 | beloha
# Processing Record 23 of Set 8 | san quintin
# Processing Record 24 of Set 8 | san cristobal
# Processing Record 25 of Set 8 | chagoda
# Processing Record 26 of Set 8 | buraydah
# Processing Record 27 of Set 8 | troitskoye
# Processing Record 28 of Set 8 | riyadh
# Processing Record 29 of Set 8 | bubaque
# Processing Record 30 of Set 8 | cape elizabeth
# City not found. Skipping...
# Processing Record 31 of Set 8 | elizabeth city
# Processing Record 32 of Set 8 | roebourne
# Processing Record 33 of Set 8 | champerico
# Processing Record 34 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 8 | hlohovec
# Processing Record 36 of Set 8 | kumluca
# Processing Record 37 of Set 8 | filadelfia
# Processing Record 38 of Set 8 | mirina
# City not found. Skipping...
# Processing Record 39 of Set 8 | seoul
# Processing Record 40 of Set 8 | san jeronimito
# Processing Record 41 of Set 8 | karratha
# Processing Record 42 of Set 8 | saskylakh
# Processing Record 43 of Set 8 | cairns
# Processing Record 44 of Set 8 | klaksvik
# Processing Record 45 of Set 8 | qabis
# City not found. Skipping...
# Processing Record 46 of Set 8 | gilbues
# Processing Record 47 of Set 8 | allonnes
# Processing Record 48 of Set 8 | okato
# Processing Record 49 of Set 8 | te anau
# Processing Record 50 of Set 8 | utraula
# Processing Record 1 of Set 9 | xiaolan
# Processing Record 2 of Set 9 | mahon
# Processing Record 3 of Set 9 | port hedland
# Processing Record 4 of Set 9 | santa maria
# Processing Record 5 of Set 9 | lipin bor
# Processing Record 6 of Set 9 | mao
# Processing Record 7 of Set 9 | bolshiye uki
# City not found. Skipping...
# Processing Record 8 of Set 9 | brekstad
# Processing Record 9 of Set 9 | nexo
# Processing Record 10 of Set 9 | grand gaube
# Processing Record 11 of Set 9 | chara
# Processing Record 12 of Set 9 | lingdong
# Processing Record 13 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 14 of Set 9 | havre-saint-pierre
# Processing Record 15 of Set 9 | rawson
# Processing Record 16 of Set 9 | buriti alegre
# Processing Record 17 of Set 9 | kilindoni
# Processing Record 18 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 20 of Set 9 | eskasem
# City not found. Skipping...
# Processing Record 21 of Set 9 | pringsewu
# Processing Record 22 of Set 9 | kandrian
# Processing Record 23 of Set 9 | baherden
# Processing Record 24 of Set 9 | aksu
# Processing Record 25 of Set 9 | kirakira
# Processing Record 26 of Set 9 | awbari
# Processing Record 27 of Set 9 | leshukonskoye
# Processing Record 28 of Set 9 | najran
# Processing Record 29 of Set 9 | bogotol
# Processing Record 30 of Set 9 | pundaguitan
# Processing Record 31 of Set 9 | vagay
# Processing Record 32 of Set 9 | lar
# Processing Record 33 of Set 9 | humberto de campos
# Processing Record 34 of Set 9 | lydenburg
# Processing Record 35 of Set 9 | marzuq
# Processing Record 36 of Set 9 | henties bay
# Processing Record 37 of Set 9 | north platte
# Processing Record 38 of Set 9 | kindu
# Processing Record 39 of Set 9 | cap malheureux
# Processing Record 40 of Set 9 | port-gentil
# Processing Record 41 of Set 9 | tarko-sale
# Processing Record 42 of Set 9 | pisco
# Processing Record 43 of Set 9 | simao
# Processing Record 44 of Set 9 | pitimbu
# Processing Record 45 of Set 9 | clovis
# Processing Record 46 of Set 9 | oloron-sainte-marie
# Processing Record 47 of Set 9 | kalengwa
# Processing Record 48 of Set 9 | nelson bay
# Processing Record 49 of Set 9 | middle island
# Processing Record 50 of Set 9 | gairo
# Processing Record 1 of Set 10 | lubango
# Processing Record 2 of Set 10 | mayo
# Processing Record 3 of Set 10 | yar-sale
# Processing Record 4 of Set 10 | ocampo
# Processing Record 5 of Set 10 | gillette
# Processing Record 6 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 7 of Set 10 | lata
# Processing Record 8 of Set 10 | sur
# Processing Record 9 of Set 10 | puerto maldonado
# Processing Record 10 of Set 10 | ketchikan
# Processing Record 11 of Set 10 | burley
# Processing Record 12 of Set 10 | ongandjera
# Processing Record 13 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 10 | muroto
# Processing Record 15 of Set 10 | hobyo
# Processing Record 16 of Set 10 | zhanaozen
# Processing Record 17 of Set 10 | nanortalik
# Processing Record 18 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 19 of Set 10 | bogale
# Processing Record 20 of Set 10 | kargasok
# Processing Record 21 of Set 10 | pontes e lacerda
# Processing Record 22 of Set 10 | nizhneudinsk
# Processing Record 23 of Set 10 | santa rosa
# Processing Record 24 of Set 10 | rodrigues alves
# Processing Record 25 of Set 10 | koboko
# Processing Record 26 of Set 10 | nhulunbuy
# Processing Record 27 of Set 10 | skjervoy
# Processing Record 28 of Set 10 | necochea
# Processing Record 29 of Set 10 | atasu
# Processing Record 30 of Set 10 | rivne
# Processing Record 31 of Set 10 | yumen
# Processing Record 32 of Set 10 | lidkoping
# Processing Record 33 of Set 10 | ciudad bolivar
# Processing Record 34 of Set 10 | mandalgovi
# Processing Record 35 of Set 10 | los algarrobos
# Processing Record 36 of Set 10 | bardiyah
# Processing Record 37 of Set 10 | palmas
# Processing Record 38 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 39 of Set 10 | shelburne
# Processing Record 40 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 41 of Set 10 | shingu
# Processing Record 42 of Set 10 | ostrovnoy
# Processing Record 43 of Set 10 | jutai
# Processing Record 44 of Set 10 | pailon
# Processing Record 45 of Set 10 | aniva
# Processing Record 46 of Set 10 | ahuimanu
# Processing Record 47 of Set 10 | port augusta
# Processing Record 48 of Set 10 | yanchukan
# City not found. Skipping...
# Processing Record 49 of Set 10 | kilinochchi
# Processing Record 50 of Set 10 | popondetta
# Processing Record 1 of Set 11 | yaviza
# Processing Record 2 of Set 11 | raga
# Processing Record 3 of Set 11 | cayenne
# Processing Record 4 of Set 11 | morvi
# Processing Record 5 of Set 11 | vangaindrano
# Processing Record 6 of Set 11 | mateo
# Processing Record 7 of Set 11 | ballina
# Processing Record 8 of Set 11 | acajutla
# Processing Record 9 of Set 11 | zaysan
# Processing Record 10 of Set 11 | ancud
# Processing Record 11 of Set 11 | vitim
# Processing Record 12 of Set 11 | acari
# Processing Record 13 of Set 11 | kuldur
# Processing Record 14 of Set 11 | thinadhoo
# Processing Record 15 of Set 11 | gongzhuling
# Processing Record 16 of Set 11 | laizhou
# Processing Record 17 of Set 11 | maiduguri
# Processing Record 18 of Set 11 | verkhoyansk
# Processing Record 19 of Set 11 | vaitape
# Processing Record 20 of Set 11 | oranjestad
# Processing Record 21 of Set 11 | bobon
# Processing Record 22 of Set 11 | noumea
# Processing Record 23 of Set 11 | madridejos
# Processing Record 24 of Set 11 | manggar
# Processing Record 25 of Set 11 | acapulco
# Processing Record 26 of Set 11 | hue
# Processing Record 27 of Set 11 | safaga
# Processing Record 28 of Set 11 | nisia floresta
# Processing Record 29 of Set 11 | bentonville
# Processing Record 30 of Set 11 | tomball
# Processing Record 31 of Set 11 | coquimbo
# Processing Record 32 of Set 11 | tranas
# Processing Record 33 of Set 11 | dicabisagan
# Processing Record 34 of Set 11 | sarangani
# Processing Record 35 of Set 11 | tilichiki
# Processing Record 36 of Set 11 | shenjiamen
# Processing Record 37 of Set 11 | vestmanna
# Processing Record 38 of Set 11 | west bay
# Processing Record 39 of Set 11 | maridi
# Processing Record 40 of Set 11 | luancheng
# Processing Record 41 of Set 11 | chlorakas
# Processing Record 42 of Set 11 | lakatoro
# Processing Record 43 of Set 11 | lago da pedra
# Processing Record 44 of Set 11 | asayita
# City not found. Skipping...
# Processing Record 45 of Set 11 | kaeo
# Processing Record 46 of Set 11 | lompoc
# Processing Record 47 of Set 11 | fort nelson
# Processing Record 48 of Set 11 | manuk mangkaw
# Processing Record 49 of Set 11 | nargana
# Processing Record 50 of Set 11 | muli
# Processing Record 1 of Set 12 | sawtell
# Processing Record 2 of Set 12 | tecoanapa
# Processing Record 3 of Set 12 | kovdor
# Processing Record 4 of Set 12 | spilamberto
# Processing Record 5 of Set 12 | antofagasta
# Processing Record 6 of Set 12 | lamar
# Processing Record 7 of Set 12 | baoshan
# Processing Record 8 of Set 12 | kabinda
# Processing Record 9 of Set 12 | nchelenge
# Processing Record 10 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 11 of Set 12 | ixtapa
# Processing Record 12 of Set 12 | virginia beach
# Processing Record 13 of Set 12 | hofn
# Processing Record 14 of Set 12 | suibara
# Processing Record 15 of Set 12 | gat
# Processing Record 16 of Set 12 | portland
# Processing Record 17 of Set 12 | lucapa
# Processing Record 18 of Set 12 | tezonapa
# Processing Record 19 of Set 12 | pozo colorado
# Processing Record 20 of Set 12 | inhambane
# Processing Record 21 of Set 12 | hervey bay
# Processing Record 22 of Set 12 | gizo
# Processing Record 23 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 12 | hastings
# Processing Record 25 of Set 12 | kieta
# Processing Record 26 of Set 12 | egvekinot
# Processing Record 27 of Set 12 | yerofey pavlovich
# Processing Record 28 of Set 12 | tual
# Processing Record 29 of Set 12 | phalodi
# Processing Record 30 of Set 12 | cidreira
# Processing Record 31 of Set 12 | tamiahua
# Processing Record 32 of Set 12 | luzon
# Processing Record 33 of Set 12 | sabanalarga
# Processing Record 34 of Set 12 | broken hill
# Processing Record 35 of Set 12 | melito di porto salvo
# Processing Record 36 of Set 12 | kavaratti
# Processing Record 37 of Set 12 | wuda
# Processing Record 38 of Set 12 | lisakovsk
# Processing Record 39 of Set 12 | paracatu
# Processing Record 40 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 41 of Set 12 | labrea
# Processing Record 42 of Set 12 | marabba
# Processing Record 43 of Set 12 | ormara
# Processing Record 44 of Set 12 | samarai
# Processing Record 45 of Set 12 | florence
# Processing Record 46 of Set 12 | provideniya
# Processing Record 47 of Set 12 | tomohon
# Processing Record 48 of Set 12 | mersing
# Processing Record 49 of Set 12 | kerema
# Processing Record 50 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 1 of Set 13 | salalah
# Processing Record 2 of Set 13 | okha
# Processing Record 3 of Set 13 | surskoye
# Processing Record 4 of Set 13 | sao jose da coroa grande
# Processing Record 5 of Set 13 | saint george
# Processing Record 6 of Set 13 | kailua
# Processing Record 7 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 13 | yanam
# Processing Record 9 of Set 13 | pyay
# Processing Record 10 of Set 13 | pokaran
# Processing Record 11 of Set 13 | barcelos
# Processing Record 12 of Set 13 | nouakchott
# Processing Record 13 of Set 13 | daosa
# City not found. Skipping...
# Processing Record 14 of Set 13 | coahuayana
# Processing Record 15 of Set 13 | kayes
# Processing Record 16 of Set 13 | morrope
# Processing Record 17 of Set 13 | skaudvile
# Processing Record 18 of Set 13 | bridlington
# Processing Record 19 of Set 13 | tokzar
# City not found. Skipping...
# Processing Record 20 of Set 13 | sorland
# Processing Record 21 of Set 13 | bumba
# Processing Record 22 of Set 13 | olinda
# Processing Record 23 of Set 13 | zastron
# Processing Record 24 of Set 13 | bereda
# Processing Record 25 of Set 13 | izhma
# Processing Record 26 of Set 13 | ipixuna
# Processing Record 27 of Set 13 | nabire
# Processing Record 28 of Set 13 | bulawayo
# Processing Record 29 of Set 13 | kim
# Processing Record 30 of Set 13 | tongchuan
# Processing Record 31 of Set 13 | manakara
# Processing Record 32 of Set 13 | mamakan
# Processing Record 33 of Set 13 | gazanjyk
# Processing Record 34 of Set 13 | norsup
# Processing Record 35 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 13 | mayumba
# Processing Record 37 of Set 13 | bikin
# Processing Record 38 of Set 13 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 39 of Set 13 | college
# Processing Record 40 of Set 13 | kununurra
# Processing Record 41 of Set 13 | north battleford
# Processing Record 42 of Set 13 | garissa
# Processing Record 43 of Set 13 | fairbanks
# Processing Record 44 of Set 13 | ostersund
# Processing Record 45 of Set 13 | muncar
# Processing Record 46 of Set 13 | marion
# Processing Record 47 of Set 13 | dosso
# Processing Record 48 of Set 13 | yuancheng
# Processing Record 49 of Set 13 | sekoma
# Processing Record 50 of Set 13 | santa cruz
# Processing Record 1 of Set 14 | port keats
# Processing Record 2 of Set 14 | dargaville
# Processing Record 3 of Set 14 | tsabong
# Processing Record 4 of Set 14 | santa marta
# Processing Record 5 of Set 14 | pergine valsugana
# Processing Record 6 of Set 14 | nong bua
# Processing Record 7 of Set 14 | oksovskiy
# Processing Record 8 of Set 14 | neyshabur
# Processing Record 9 of Set 14 | manzhouli
# Processing Record 10 of Set 14 | bafq
# Processing Record 11 of Set 14 | abu zabad
# Processing Record 12 of Set 14 | balakhta
# Processing Record 13 of Set 14 | berlevag
# Processing Record 14 of Set 14 | utena
# Processing Record 15 of Set 14 | chumikan
# Processing Record 16 of Set 14 | keti bandar
# Processing Record 17 of Set 14 | margate
# Processing Record 18 of Set 14 | ishigaki
# Processing Record 19 of Set 14 | xining
# Processing Record 20 of Set 14 | goderich
# Processing Record 21 of Set 14 | arvika
# Processing Record 22 of Set 14 | juchipila
# Processing Record 23 of Set 14 | vallenar
# Processing Record 24 of Set 14 | chifeng
# Processing Record 25 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 26 of Set 14 | redlands
# Processing Record 27 of Set 14 | rapid valley
# Processing Record 28 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 14 | siderno
# Processing Record 30 of Set 14 | gurskoye
# City not found. Skipping...
# Processing Record 31 of Set 14 | tromso
# Processing Record 32 of Set 14 | lazaro cardenas
# Processing Record 33 of Set 14 | auka
# Processing Record 34 of Set 14 | quatre cocos
# Processing Record 35 of Set 14 | vinh
# Processing Record 36 of Set 14 | kapuskasing
# Processing Record 37 of Set 14 | miramar
# Processing Record 38 of Set 14 | sistranda
# Processing Record 39 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 14 | kokopo
# Processing Record 41 of Set 14 | danjiangkou
# Processing Record 42 of Set 14 | broome
# Processing Record 43 of Set 14 | alice springs
# Processing Record 44 of Set 14 | bogorodskoye
# Processing Record 45 of Set 14 | tupik
# Processing Record 46 of Set 14 | baymak
# Processing Record 47 of Set 14 | atambua
# Processing Record 48 of Set 14 | salta
# Processing Record 49 of Set 14 | bayan
# Processing Record 50 of Set 14 | guarapari
# Processing Record 1 of Set 15 | puerto escondido
# Processing Record 2 of Set 15 | sombrerete
# Processing Record 3 of Set 15 | mingyue
# Processing Record 4 of Set 15 | qandala
# Processing Record 5 of Set 15 | kadan
# Processing Record 6 of Set 15 | kibiti
# Processing Record 7 of Set 15 | kuryk
# Processing Record 8 of Set 15 | otjimbingwe
# Processing Record 9 of Set 15 | nishihara
# Processing Record 10 of Set 15 | sinnamary
# Processing Record 11 of Set 15 | jujuy
# City not found. Skipping...
# Processing Record 12 of Set 15 | mangan
# Processing Record 13 of Set 15 | kalaleh
# Processing Record 14 of Set 15 | sibu
# Processing Record 15 of Set 15 | sibolga
# Processing Record 16 of Set 15 | san ramon de la nueva oran
# Processing Record 17 of Set 15 | arlit
# Processing Record 18 of Set 15 | novobessergenevka
# Processing Record 19 of Set 15 | manga
# Processing Record 20 of Set 15 | valparaiso
# Processing Record 21 of Set 15 | iquitos
# Processing Record 22 of Set 15 | kommunisticheskiy
# Processing Record 23 of Set 15 | norwich
# Processing Record 24 of Set 15 | ratnagiri
# Processing Record 25 of Set 15 | khelyulya
# Processing Record 26 of Set 15 | zholymbet
# Processing Record 27 of Set 15 | port macquarie
# Processing Record 28 of Set 15 | balta
# Processing Record 29 of Set 15 | tres arroyos
# Processing Record 30 of Set 15 | pangnirtung
# Processing Record 31 of Set 15 | wajir
# Processing Record 32 of Set 15 | kamachumu
# Processing Record 33 of Set 15 | plouzane
# Processing Record 34 of Set 15 | risor
# Processing Record 35 of Set 15 | duluth
# Processing Record 36 of Set 15 | hovd
# Processing Record 37 of Set 15 | heihe
# Processing Record 38 of Set 15 | poso
# Processing Record 39 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 40 of Set 15 | bhuj
# Processing Record 41 of Set 15 | raudeberg
# Processing Record 42 of Set 15 | ruidoso
# Processing Record 43 of Set 15 | schwedt
# Processing Record 44 of Set 15 | sal rei
# Processing Record 45 of Set 15 | mindyak
# Processing Record 46 of Set 15 | lahat
# Processing Record 47 of Set 15 | yelabuga
# Processing Record 48 of Set 15 | weihe
# Processing Record 49 of Set 15 | birao
# Processing Record 50 of Set 15 | lasa
# Processing Record 1 of Set 16 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 16 | kendari
# Processing Record 3 of Set 16 | fort abbas
# Processing Record 4 of Set 16 | sayville
# Processing Record 5 of Set 16 | eravur
# Processing Record 6 of Set 16 | wuning
# Processing Record 7 of Set 16 | udachnyy
# Processing Record 8 of Set 16 | rantepao
# Processing Record 9 of Set 16 | deloraine
# Processing Record 10 of Set 16 | talnakh
# Processing Record 11 of Set 16 | alotau
# City not found. Skipping...
# Processing Record 12 of Set 16 | vastervik
# City not found. Skipping...
# Processing Record 13 of Set 16 | szedres
# Processing Record 14 of Set 16 | buta
# Processing Record 15 of Set 16 | santarem
# Processing Record 16 of Set 16 | miyako
# Processing Record 17 of Set 16 | amot
# Processing Record 18 of Set 16 | formosa do rio preto
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Butaritari      KI   3.0707  172.7902     82.45        74          38
# 1        Westport      US  41.1415  -73.3579     86.18        57           1
# 2       Busselton      AU -33.6500  115.3333     59.09        84         100
# 3         Ushuaia      AR -54.8000  -68.3000     31.66        93           0
# 4           Bluff      NZ -46.6000  168.3333     49.80        71          74
# 5          Narsaq      GL  60.9167  -46.0500     46.62        79         100
# 6         Shimoda      JP  34.6667  138.9500     68.36        94         100
# 7    Saint-Joseph      RE -21.3667   55.6167     71.47        84          35
# 8         Rikitea      PF -23.1203 -134.9692     76.12        79           8
# 9  Port Elizabeth      ZA -33.9180   25.5701     53.89        82           0
#
#    Wind Speed Current Description
# 0        7.49          light rain
# 1       11.61           clear sky
# 2       10.25     overcast clouds
# 3        4.61           clear sky
# 4        5.77       broken clouds
# 5        6.69     overcast clouds
# 6        5.06          light rain
# 7        1.97          light rain
# 8       13.02           clear sky
# 9        9.22           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
